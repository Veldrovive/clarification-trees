# %%
from dataset import ClearVQADataset
from IPython.display import display

# %%
ds = ClearVQADataset()
# Out:
# Loading table...
# Finished loading tables
# Train headers: Index(['question_id', 'question', 'gold_answer', 'image', 'answers', 'dataset',
#        'caption', 'blurred_question', 'clarification_question', 'prompt_type'],
#       dtype='object')

# %%
img, sample = ds[0]
display(img)
print(f"Question: {sample['question']}")
print(f"Blurred Question: {sample['blurred_question']}")
print(f"Answer: {sample['gold_answer']} ({sample['answers']})")
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>
# Question: What are the clear circles on the front of the car made of?
# Blurred Question: What are they made of?
# Answer: glass (['glass', 'glass', 'glass', 'lights', 'glass', 'glass', 'glass', 'glass', 'glass', 'silver rod'])
